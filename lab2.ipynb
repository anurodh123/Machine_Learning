# %% [markdown]
# <a href="https://colab.research.google.com/github/avashachhami/Machine-Learning-/blob/main/lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to Colab!

# %%
d = { "a":1,"b":2}

# %%
d["a"]
# Out:
# 1

# %%
d.get("a")
# Out:
# 1

# %%
d["c"]=3

# %%
d["a"]=10

# %%
del d["b"]

# %%
d.pop("a")
# Out:
# 10

# %%
d.popitem()
# Out:
# ('c', 3)

# %%
d.clear()

# %%
new_d=d.copy()

# %%
d.keys()
# Out:
# dict_keys([])

# %%
d.values()
# Out:
# dict_values([])

# %%
d.items()
# Out:
# dict_items([])

# %%
"a" in d
# Out:
# False

# %%
len(d)
# Out:
# 0

# %%
for k in d:
    pass

# %%
for v in d.values():
    pass

# %%
for k,v in d.items():
    pass

# %%
import pandas as pd

# %%
df = pd.DataFrame(columns = [
    {'Name': 'Avash Achhami', 'Age': 20, 'Marks': 88},
    {'Name': 'Preeti Shrestha', 'Age': 19, 'Marks': 98},
    {'Name': 'Songol Chettri', 'Age': 20, 'Marks': 88},
    {'Name': 'Ram hari Krishna', 'Age': 34 , 'Marks':22 },
    {'Name': 'Anurod Kharel', 'Age':21 , 'Marks':100 },
    {'Name': 'Ashim Shretha', 'Age':20 , 'Marks':300 },
    {'Name': 'Subodh Upreti', 'Age':22 , 'Marks':7 },
])

# %%
data = [
    {'Name': 'Avash Achhami', 'Age': 20, 'Marks': 88},
    {'Name': 'Preeti Shrestha', 'Age': 19, 'Marks': 98},
    {'Name': 'Songol Chettri', 'Age': 20, 'Marks': 88},
    {'Name': 'Ram hari Krishna', 'Age': 34 , 'Marks':22 },
    {'Name': 'Anurod Kharel', 'Age':21 , 'Marks':100 },
    {'Name': 'Ashim Shretha', 'Age':20 , 'Marks':300 },
    {'Name': 'Subodh Upreti', 'Age':22 , 'Marks':7 },
]

# %%
display(df.tail())
# Out:
#                Name  Age  Marks
# 2    Songol Chettri   20     88
# 3  Ram hari Krishna   34     22
# 4     Anurod Kharel   21    100
# 5     Ashim Shretha   20    300
# 6     Subodh Upreti   22      7

# %%
df.shape
# Out:
# (7, 3)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Marks'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    7 non-null      object
#  1   Age     7 non-null      int64
#  2   Marks   7 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 300.0+ bytes

# %%
df.describe()
# Out:
#              Age       Marks
# count   7.000000    7.000000
# mean   22.285714  100.428571
# std     5.250850   95.763349
# min    19.000000    7.000000
# 25%    20.000000   55.000000
# 50%    20.000000   88.000000
# 75%    21.500000   99.000000
# max    34.000000  300.000000

# %%
df['Name']
# Out:
# 0       Avash Achhami
# 1     Preeti Shrestha
# 2      Songol Chettri
# 3    Ram hari Krishna
# 4       Anurod Kharel
# 5       Ashim Shretha
# 6       Subodh Upreti
# Name: Name, dtype: object

# %%
df[['Name','Marks']]
# Out:
#                Name  Marks
# 0     Avash Achhami     88
# 1   Preeti Shrestha     98
# 2    Songol Chettri     88
# 3  Ram hari Krishna     22
# 4     Anurod Kharel    100
# 5     Ashim Shretha    300
# 6     Subodh Upreti      7

# %%
df.iloc[0]
# Out:
# Name     Avash Achhami
# Age                 20
# Marks               88
# Name: 0, dtype: object

# %%
df.loc[0,'Marks']
# Out:
# np.int64(88)

# %%
df[df['Marks']>90]
# Out:
#               Name  Age  Marks
# 1  Preeti Shrestha   19     98
# 4    Anurod Kharel   21    100
# 5    Ashim Shretha   20    300

# %%
df[(df['Marks']>90) & (df['Age']>20)]
# Out:
#             Name  Age  Marks
# 4  Anurod Kharel   21    100

# %%
df['Grade'] = ['A', 'B', 'A', 'C', 'A', 'D', 'B']
display(df)
# Out:
#                Name  Age  Marks Grade
# 0     Avash Achhami   20     88     A
# 1   Preeti Shrestha   19     98     B
# 2    Songol Chettri   20     88     A
# 3  Ram hari Krishna   34     22     C
# 4     Anurod Kharel   21    100     A
# 5     Ashim Shretha   20    300     D
# 6     Subodh Upreti   22      7     B

# %%
df['Marks']=df['Marks']+5
display(df)
# Out:
#                Name  Age  Marks Grade
# 0     Avash Achhami   20     93     A
# 1   Preeti Shrestha   19    103     B
# 2    Songol Chettri   20     93     A
# 3  Ram hari Krishna   34     27     C
# 4     Anurod Kharel   21    105     A
# 5     Ashim Shretha   20    305     D
# 6     Subodh Upreti   22     12     B

# %%
df.loc[df['Name']=='Ram hari Krishna','Marks']=95
display(df)
# Out:
#                Name  Age  Marks Grade
# 0     Avash Achhami   20     93     A
# 1   Preeti Shrestha   19    103     B
# 2    Songol Chettri   20     93     A
# 3  Ram hari Krishna   34     95     C
# 4     Anurod Kharel   21    105     A
# 5     Ashim Shretha   20    305     D
# 6     Subodh Upreti   22     12     B

# %%
df.drop('Age',axis=1)
# Out:
#                Name  Marks Grade
# 0     Avash Achhami     93     A
# 1   Preeti Shrestha    103     B
# 2    Songol Chettri     93     A
# 3  Ram hari Krishna     95     C
# 4     Anurod Kharel    105     A
# 5     Ashim Shretha    305     D
# 6     Subodh Upreti     12     B

# %%
df.sort_values(by='Marks')
# Out:
#                Name  Age  Marks Grade
# 6     Subodh Upreti   22     12     B
# 0     Avash Achhami   20     93     A
# 2    Songol Chettri   20     93     A
# 3  Ram hari Krishna   34     95     C
# 1   Preeti Shrestha   19    103     B
# 4     Anurod Kharel   21    105     A
# 5     Ashim Shretha   20    305     D

# %%
df.sort_values(by='Marks',ascending=False)
# Out:
#                Name  Age  Marks Grade
# 5     Ashim Shretha   20    305     D
# 4     Anurod Kharel   21    105     A
# 1   Preeti Shrestha   19    103     B
# 3  Ram hari Krishna   34     95     C
# 0     Avash Achhami   20     93     A
# 2    Songol Chettri   20     93     A
# 6     Subodh Upreti   22     12     B

# %%
pd.concat([df,df])
# Out:
#                Name  Age  Marks Grade
# 0     Avash Achhami   20     93     A
# 1   Preeti Shrestha   19    103     B
# 2    Songol Chettri   20     93     A
# 3  Ram hari Krishna   34     95     C
# 4     Anurod Kharel   21    105     A
# 5     Ashim Shretha   20    305     D
# 6     Subodh Upreti   22     12     B
# 0     Avash Achhami   20     93     A
# 1   Preeti Shrestha   19    103     B
# 2    Songol Chettri   20     93     A
# 3  Ram hari Krishna   34     95     C
# 4     Anurod Kharel   21    105     A
# 5     Ashim Shretha   20    305     D
# 6     Subodh Upreti   22     12     B

# %%
pd.read_csv('file.csv')
# Out:
#                          Industry
# 0              Accounting/Finance
# 1    Advertising/Public Relations
# 2              Aerospace/Aviation
# 3   Arts/Entertainment/Publishing
# 4                      Automotive
# 5                Banking/Mortgage
# 6            Business Development
# 7            Business Opportunity
# 8         Clerical/Administrative
# 9         Construction/Facilities
# 10                 Consumer Goods
# 11               Customer Service
# 12             Education/Training
# 13               Energy/Utilities
# 14                    Engineering
# 15            Government/Military
# 16                          Green
# 17                     Healthcare
# 18             Hospitality/Travel
# 19                Human Resources
# 20       Installation/Maintenance
# 21                      Insurance
# 22                       Internet
# 23                Job Search Aids
# 24       Law Enforcement/Security
# 25                          Legal
# ...

# %%
df.to_csv('file.csv')

# %%
pd.read_excel('file.xlsx')
# Out:
#      anurod
# 0     avash
# 1  dindayal
# 2     ashim
# 3    subodh
# 4  dikshant
# 5    jigmet
# 6    sangat
# 7    sudeep
